# %% [markdown]
# # Google Cloud Functions Course
# Para empezar un nuevo proyecto en Google Cloud, podemos ir a [Firebase Console](https://console.firebase.google.com) o a [Cloud Platform Console](https://console.cloud.google.com).
#
# Iniciamos GIT

# %% [raw]
# git init

# %% [markdown]
# ![image.png](attachment:49a13be3-a362-4a79-96fa-32a65fcf1db3.png)
#
# Copiamos sólo la siguiente línea

# %% [raw]
# git remote add origin https://github.com/Saitam/Google-Cloud-Functions-Course.git

# %% [markdown]
# Cambiamos de carpeta con ls

# %% [markdown]
# Para configurar el GITHUT por primera vez, tenemos que usar el siguiente código

# %% [raw]
# git config --global user.mail "saitam.merino@gmail.com"
# git config --global user.name "Matías"

# %% [markdown]
# Agregamos Archivos y hacemos nuestro primer commit

# %% [raw]
# git add .
# git commit -m "First commit"
